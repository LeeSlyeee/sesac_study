# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import korean
import pandas as pd
import numpy as np
import seaborn as sns 
import folium

# %%
map_osm = folium.Map(location=[45.5236,-122.6750], zoom_start=13)
map_osm
# Out:
# <folium.folium.Map object at 0x000002BEC25C8EC0>
